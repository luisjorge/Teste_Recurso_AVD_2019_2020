# %% [markdown]
# ## Teste de Recurso (segunda parte)
#
# ### As suas respostas deverão ser feitas nas células de código (input) correspondentes a cada pergunta.

# %% [markdown]
# No diretório deste notebook tem um ficheiro csv ("mndicadores_cidades_portuguesas.csv") com alguns indicadores sobre a forma como as pessoas como se deslocam nas cidades portuguesas. Os campos NUTS 3, NUTS2 e NUTS 1 correspondem à "Nomenclatura das Unidades Territoriais para Fins Estatísticos”, sistema hierárquico de divisão do território em regiões.

# %% [markdown]
# **1 - Abra o ficheiro mobilidade_cidades_portuguesas.csv e apresente uma listagem das colunas presentes no mesmo, utilizando o módulo Pandas de python (0,5 valores)**

# %% [markdown]
# **2 - Calcule e apresente o número total de pessoas que se descolam a pé (coluna "A pé") (1 valor)**

# %% [markdown]
# **3 - Calcule e apresente a média do número de pessoas que se deslocam de bicicleta nas cidades portuguesas (1,5 valores)**

# %% [markdown]
# **4 - Calcule o número total de pessoas que se deslocam a pé e de bicicleta nas cidades portuguesas, agrupadas por NUTS 2 (2 valores)**

# %% [markdown]
# **5 - Quais são as cidades com mais de quinhentas (500) pessoas que se deslocam de bicicleta? (2 valores)**

# %% [markdown]
# **6 - Apresente uma listagem da contagem de valores nulos nas colunas (0,5 valores)**

# %% [markdown]
# **7 - Calcule e apresente o número de registos por distrito (0,5 valores)**

# %% [markdown]
# **8 - Construa um gráfico de dispersão ("scatter plot") utilizando a biblioteca seaborn com as pessoas que se deslocam a pé e de bicicleta, com cores por NUTS 2, como apresentado na seguinte figura): (2 valores)
# ![title](grafico.png)**
